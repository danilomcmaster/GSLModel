# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

import numpy as np
import matplotlib.pyplot as plt
import model_funcs as mf
import pandas as pd
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
t = np.linspace(0, 1000, 1001)

plt.plot(t, mf.basic_inflow(0, t))
plt.xlabel('Time (days)')
plt.ylabel('Inflow in acre-feet')
plt.title('Basic Inflow Over Time')
plt.show()

# %%
#test evaporation function
def test_evaporation(x, t):
    mean = 2100000 / 365
    return np.sin(2 * np.pi * (t - 180) / 365) * 500 + mean

# %%
# test ODE
ode = lambda x, t: mf.basic_inflow(0, t) - test_evaporation(x, t)
t = np.linspace(0, 1000, 1001)
x0 = np.array([2000000])

sol = mf.rk4(ode, x0, t)
plt.plot(t, sol[:, 0])

# %%
data = pd.read_csv("/Users/taylorlee/Documents/School/2026 Winter/Math 436/GSLModel/data/GSLLevelVol.csv")

# %%
data.head()
# Out:
#          Date   S_level_ft   N_level_ft    S_level_m    N_level_m  \
# 0  1847-11-01  4199.864615  4199.864615  1280.118735  1280.118735
# 1  1847-12-01  4200.003077  4200.003077  1280.160938  1280.160938
# 2  1848-01-01  4200.146154  4200.146154  1280.204548  1280.204548
# 3  1848-02-01  4200.289231  4200.289231  1280.248158  1280.248158
# 4  1848-03-01  4200.423077  4200.423077  1280.288954  1280.288954
#
#       S_area_m2     N_area_m2      S_vol_m3      N_vol_m3  Total_vol_m3  \
# 0  2.643110e+09  1.547986e+09  1.194469e+10  6.958589e+09  1.890328e+10
# 1  2.668944e+09  1.555834e+09  1.205525e+10  7.023666e+09  1.907892e+10
# 2  2.701545e+09  1.559613e+09  1.217513e+10  7.091888e+09  1.926702e+10
# 3  2.734145e+09  1.563391e+09  1.229501e+10  7.160110e+09  1.945512e+10
# 4  2.764642e+09  1.566926e+09  1.240715e+10  7.223930e+09  1.963108e+10
#
#       natlev_m    natlev_ft
# 0  1280.118735  4199.864615
# 1  1280.160938  4200.003077
# 2  1280.204548  4200.146154
# ...
